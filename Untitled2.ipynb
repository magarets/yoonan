# %% [markdown]
# <a href="https://colab.research.google.com/github/magarets/yoonan/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sentence_transformers import SentenceTransformer, util

# %%
from pororo import Pororo
import pandas as pd
from sentence_transformers import util
import torch
import numpy as np
import urllib.request

# %%
import xlrd
import copy

# %%
# 한글 맞춤법(띄어쓰기) 수정
spacing = Pororo(task="gec", lang="ko")

# 오류 문장 입력
spacing("아버지가방에들어간다.")
# Out:
# As of now, this beta model tries to correct spacing errors in Korean text.
# '아버지가 방에 들어간다.'

# %%
# 모델 설정
model = AutoTokenizer.from_pretrained("beomi/KcELECTRA-base")

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
# 구글 드라이브 연동
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# 파일 읽어오기
fd = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/models/train_data.xlsx')

# %%
print(fd['Embedding'])
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 38589   NaN
# 38590   NaN
# 38591   NaN
# 38592   NaN
# 38593   NaN
# Name: Embedding, Length: 38594, dtype: float64

# %%
fd['Embedding'] = pd.Series([[]] * len(fd))

# %%
# 설정한 모델로 벡터화
fd['Embedding'] = fd['Sentence'].map(lambda x: list(model.encode(x)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-185-75ae89ef3ee3> in <module>()
#       1 # 설정한 모델로 벡터화
# ----> 2 fd['Embedding'] = fd['Sentence'].map(lambda x: list(model.encode(x)))
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in map(self, arg, na_action)
#    4159         dtype: object
#    4160         """
# -> 4161         new_values = super()._map_values(arg, na_action=na_action)
#    4162         return self._constructor(new_values, index=self.index).__finalize__(
#    4163             self, method="map"
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     868
#     869         # mapper is a function
# --> 870         new_values = map_f(values, mapper)
#     871
#     872         return new_values
#
# ...

# %%
print(fd['Embedding'].head())
# Out:
# 0    [2, 24294, 13322, 7973, 17986, 4131, 8660, 210...
# 1             [2, 8022, 613, 9904, 10000, 8115, 33, 3]
# 2    [2, 8135, 12037, 4474, 22904, 4033, 10502, 443...
# 3              [2, 11623, 19413, 8492, 11120, 8329, 3]
# 4          [2, 8249, 8882, 12736, 4070, 4465, 8234, 3]
# Name: Embedding, dtype: object

# %%
# 임베딩의 최대 길이 구하기
# max = 150

# 최대 길이만큼 0으로 패딩

count = 1
max = 150
for list in fd['Embedding']:
  list = list.tolist()
  
  print(type(list))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-176-460175026beb> in <module>()
#       7 max = 150
#       8 for list in fd['Embedding']:
# ----> 9   list = list.tolist()
#      10
#      11   print(type(list))
#
# AttributeError: 'str' object has no attribute 'tolist'

# %%
# 벡터로 변환된 데이터 저장
fd.to_excel('/content/drive/MyDrive/Colab Notebooks/models/train_data_final_final_final_endgame.xlsx')

# %%
from numpy import dot
from numpy.linalg import norm
import string

# 대입
List1 = text1
List2 = text2
List1, List2

# %%
max_len = max(len(text1), len(text2))

# 0으로 패딩
if(len(text1) > len(text2)):
  for i in range(max_len - len(text2)):
    text2.append(0)

else:
  for i in range(max_len - len(text1)):
    text1.append(0)

# %%
text = '오늘 진짜 짜증나'

# 사용자 입력 벡터화
embedding = model.encode(text)

# %%
for data in fd['Embedding']:
  print(f"sim: {util.cos_sim(data, embedding)}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-110-70f6707a1096> in <module>()
#       1 for data in fd['Embedding']:
# ----> 2   print(f"sim: {util.cos_sim(data, embedding)}")
#
# /usr/local/lib/python3.7/dist-packages/sentence_transformers/util.py in cos_sim(a, b)
#      38         b = b.unsqueeze(0)
#      39
# ---> 40     a_norm = torch.nn.functional.normalize(a, p=2, dim=1)
#      41     b_norm = torch.nn.functional.normalize(b, p=2, dim=1)
#      42     return torch.mm(a_norm, b_norm.transpose(0, 1))
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in normalize(input, p, dim, eps, out)
#    3749                 normalize, (input,), input, p=p, dim=dim, eps=eps, out=out)
#    3750     if out is None:
# -> 3751         denom = input.norm(p, dim, keepdim=True).clamp_min(eps).expand_as(input)
#    3752         return input / denom
# ...

# %%
from transformers import AutoTokenizer
model2 = AutoTokenizer.from_pretrained("beomi/KcELECTRA-base")
model3 = SentenceTransformer('jhgan/ko-sroberta-multitask')
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.86k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/744 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/123 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/931 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/443M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/302 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/156 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/495k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/585 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/248k [00:00<?, ?B/s]

# %%
text1 = '사랑해'
text2 = '좋아해'

# %%
# Out:
# ([2, 8912, 4025, 3], [2, 8269, 4025, 3])

# %%
print(dot(List1, List2)/(norm(List1)*norm(List2)))
# Out:
# 0.9995858162044781
